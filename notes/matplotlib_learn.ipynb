# %% [markdown]
# ## 数据可视化
#
# 毕竟肉眼能看到数据的有效数据是有限的，图表可以很清晰的看到数据的某种关联，数据分析中非常重要的一个环节

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### 直方图

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

xs = [i + 0.1 for i, _ in enumerate(movies)]
plt.bar(xs, num_oscars, 0.8)

plt.ylabel('Osk')
plt.title('my loves')
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)
plt.show()

# %% [markdown]
# ### 曲线图

# %%
years = [1990, 1995, 2000, 2005, 2010, 2015]
gdp = [300.5, 500.3, 800.89, 900, 1500, 2000]

plt.plot(years, gdp, color="green", marker='o', linestyle='solid')
plt.title("Gdp datas")
plt.ylabel("billion")
plt.show()

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]

xs = [i for i, _ in enumerate(variance)]

# 多条曲线
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-.', label='squared')
plt.plot(xs, total_error, 'b:', label='error')

# 图例的位置
plt.legend(loc=9)
plt.xlabel("complex")
plt.title('chart')
plt.show()

# %% [markdown]
# ### 散点图

# %%
friends = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

#每个点上加一些标记
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                xy=(friend_count, minute_count),
                xytext=(5, -5),
                textcoords='offset points')

plt.scatter(friends, minutes)
plt.title('mins and friends')
plt.show()

# %% [markdown]
# lables 比较多的时候怎么按照一定的间隔取数据显示？

# %%
import random
x1 = list(range(144))
labels = [str(i) + 'x00' for i in range(144)]
y1 = [random.randint(1, 1000) for i in range(144)]
y2 = [random.randint(1, 1000) for i in range(144)]

plt.figure(figsize=(20,5))
plt.plot(x1, y1, color='green', linestyle='-')
plt.plot(x1, y2, color='blue')

plt.xticks(range(min(x1), max(x1)+1, 10), 
           [labels[i] for i in range(min(x1), max(x1)+1, 10)], 
           rotation='vertical')

#plt.fill_between(x1, y1, interpolate=True, color='green', alpha=0.5)
#plt.fill_between(x1, y2, interpolate=True, color='blue', alpha=0.5)
#plt.yticks([0, max(y1)])
plt.show()
